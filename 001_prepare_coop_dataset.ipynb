# %% [markdown]
# # Imports

# %%
import os
import sys
import pandas as pd
import numpy as np
import uuid
import json
import subprocess
from sklearn.model_selection import train_test_split
from data_processing import get_interest_frames_from_video
from download import LomotifDownloader
from tqdm import trange
from PIL import Image

# %% [markdown]
# # Read data
# This is the data you want to use to fine-tune CoOp.

# %%
df = pd.read_csv('sample_data.csv',
                 nrows=50)  # for demo, let's just look at the first 20 samples

# %%
df.head()
# Out:
#                                      ID  \
# 0  a975f22d-8faf-4b01-9012-1187f33c95c9
# 1  b7f2c47c-671b-4889-a9e1-8b9874e35e8f
# 2  4a2adbc8-cc03-4f96-96a6-83a3f09b0769
# 3  19c9d156-6056-4c47-8afa-0dc37dfd389e
# 4  6163ab3a-20dc-4d0a-b8d9-cfc6c7d134b9
#
#                                                VIDEO  \
# 0  https://lomotif-prod.s3.amazonaws.com/lomotifs...
# 1  https://lomotif-prod.s3.amazonaws.com/lomotifs...
# 2  https://lomotif-prod.s3.amazonaws.com/lomotifs...
# 3  https://lomotif-prod.s3.amazonaws.com/lomotifs...
# 4  https://lomotif-prod.s3.amazonaws.com/lomotifs...
#
#                        CREATED   PRIMARY_CATEGORIES SECONDARY_CATEGORIES  \
# 0  2022-04-10T00:46:38.025329Z                 food               recipe
# 1  2022-04-10T00:49:17.651142Z              animals                 pets
# 2  2022-04-10T01:20:43.506315Z        entertainment             romantic
# 3  2022-04-10T01:33:17.773981Z  beauty-and-grooming                 hair
# 4  2022-04-10T01:43:23.840748Z  beauty-and-grooming                 hair
#
#   COUNTRY
# 0      RU
# 1      RU
# 2      RU
# 3      RU
# 4      RU

# %% [markdown]
# # Download key frames from the lomotifs

# %%
save_dir = './downloaded_lomotifs'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
ld = LomotifDownloader(save_dir)

img_dir = './key_frames_extracted'
if not os.path.exists(img_dir):
    os.makedirs(img_dir)

# %%
for i in trange(len(df)):
    video_url = df.loc[i, 'VIDEO']
    lid = df.loc[i, 'ID']

    # download the lomotif
    result, save_file_name = ld.download(video_url=video_url, lomotif_id=lid)

    # extract key frames
    (
        key_frames,
        fps,
        num_frames,
        selected_frame_indices,
    ) = get_interest_frames_from_video(save_file_name)

    # save all key frames as images
    for frame in key_frames:
        im = Image.fromarray(frame)
        imfilename = '{}.png'.format(str(uuid.uuid4()).split('-')[0])

        if not os.path.exists(os.path.join(img_dir, lid)):
            os.makedirs(os.path.join(img_dir, lid))
        im.save(os.path.join(img_dir, lid, imfilename))

    # delete downloaded lomotif as we do not need it anymore
    os.remove(save_file_name)
# Out:
# 100%|██████████| 29/29 [01:22<00:00,  2.84s/it]

# %% [markdown]
# # Move images into folder structure required by CoOp

# %%
coop_data_dir = './CoOp/data/tagging'
if not os.path.exists(coop_data_dir):
    if not os.path.exists('./CoOp/data'):
        os.makedirs('./CoOp/data')
    os.makedirs(coop_data_dir)

# %%
# define secondary to primary category mapping
mapping = {
    'birds': 'animals',
    'domestic-animals': 'animals',
    'pets': 'animals',
    'wild-life': 'animals',
    'advertisement': 'branding-and-advertisements',
    'religious-speech': 'devotional',
    'religious-festivals': 'devotional',
    'god': 'devotional',
    'holy-places': 'devotional',
    'tutorials': 'education',
    'general-knowledge': 'education',
    'quiz': 'education',
    'performance': 'entertainment',
    'comedy': 'entertainment',
    'drama': 'entertainment',
    'meme': 'entertainment',
    'bloopers': 'entertainment',
    'funny-clips': 'entertainment',
    'funny-dubbing': 'entertainment',
    'pranks': 'entertainment',
    'romantic': 'entertainment',
    'entertainment-celebrities': 'entertainment',
    'party': 'entertainment',
    'tv-series-and-shows': 'entertainment',
    'movie': 'entertainment',
    'kids': 'family-and-friends',
    'friends': 'family-and-friends',
    'recipe': 'food',
    'street-food': 'food',
    'food-celebrities': 'food',
    'beverages': 'food',
    'desserts': 'food',
    'fitness': 'health-and-fitness',
    'shopping': 'shopping',
    'home-decor': 'home-decoration',
    'fashion': 'fashion',
    'quotes': 'inspirational',
    'attitude-motivation': 'inspirational',
    'spiritual-motivation': 'inspirational',
    'motivational-celebrities': 'inspirational',
    'car': 'automobiles',
    'motorbikes': 'automobiles',
    'trucks': 'automobiles',
    'cricket': 'sports-and-games',
    'badminton': 'sports-and-games',
    'football': 'sports-and-games',
    'wrestling': 'sports-and-games',
    'hockey': 'sports-and-games',
    'basketball': 'sports-and-games',
    'boxing': 'sports-and-games',
    'racing': 'sports-and-games',
    'swimming': 'sports-and-games',
    'sports-celebrities': 'sports-and-games',
    'bull-riding': 'sports-and-games',
    'skateboarding': 'adventure',
    'sky-diving': 'adventure',
    'bungee-jump': 'adventure',
    'wing-suit': 'adventure',
    'rope-walking': 'adventure',
    'adventure-rides': 'adventure',
    'vehicular-stunts': 'adventure',
    'surfing': 'adventure',
    'photography': 'art-and-creativity',
    'drawing-and-painting': 'art-and-creativity',
    'beach': 'travel',
    'nature': 'travel',
    'travel-vlogs': 'travel',
    'birthday': 'celebration-and-wishes',
    'other-wishes': 'celebration-and-wishes',
    'anniversary': 'celebration-and-wishes',
    'music-performance': 'music-and-singing',
    'singing': 'music-and-singing',
    'anime': 'animation',
    'gifs': 'animation',
    'cartoon': 'animation',
    'other-gaming': 'gaming',
    'dancing': 'dance',
    'dance-performance': 'dance',
    'make-up': 'beauty-and-grooming',
    'skincare': 'beauty-and-grooming',
    'hair': 'beauty-and-grooming',
    'grooming-tips': 'beauty-and-grooming',
    'nails': 'beauty-and-grooming',
    'beauty-accessories': 'beauty-and-grooming',
    'mobile-phones': 'gadgets-and-technology',
    'watches': 'gadgets-and-technology',
    'selfie': 'selfies',
    'animal-cruelty': 'animal-cruelty',
    'dead-bodies-&-corpes': 'dead-bodies-&-corpes',
    'physical-violence': 'physical-violence',
    'profanity': 'profanity',
    'visually-disturbing': 'visually-disturbing',
    'weapons-&-firearms': 'weapons-&-firearms'
}

# %%
for i in trange(len(df)):
    video_url = df.loc[i, 'VIDEO']
    lid = df.loc[i, 'ID']
    sec_cat = df.loc[i, 'SECONDARY_CATEGORIES'].split(', ')
    pri_cat = list(set([mapping[x] for x in sec_cat if x in mapping.keys()]))
    
    if len(pri_cat) > 0:
        # create a folder per class for the first time
        for label in pri_cat:
            if not os.path.exists(os.path.join(coop_data_dir, label)):
                os.makedirs(os.path.join(coop_data_dir, label))

        # move key frame images to respective class folders
        key_frame_files = os.listdir(os.path.join(img_dir, lid))

        for f in key_frame_files:
            for label in pri_cat:
                subprocess.call(['cp', os.path.join(img_dir, lid, f), os.path.join(coop_data_dir, label)])
# Out:
# 100%|██████████| 50/50 [00:08<00:00,  6.03it/s]

# %%
for f in os.listdir(coop_data_dir):
    print('{}: {} images'.format(
        f, len(os.listdir(os.path.join(coop_data_dir, f)))))
# Out:
# travel: 68 images
# beauty-and-grooming: 92 images
# adventure: 29 images
# animals: 56 images
# fashion: 131 images
# family-and-friends: 180 images
# art-and-creativity: 15 images
# food: 155 images
# dance: 8 images
# entertainment: 26 images

# %% [markdown]
# # Write json file indicating train test split

# %%
src_dir = './CoOp/data/tagging'
dict_file = {}
dict_file['train'] = []
dict_file['test'] = []
dict_file['val'] = []
dict_file
# Out:
# {'train': [], 'test': [], 'val': []}

# %%
idxnew = 0
for idx, i in enumerate(os.listdir(src_dir)):
    train, test = train_test_split(os.listdir(os.path.join(src_dir, i)),
                                   test_size=0.8,
                                   random_state=123)
    test_new, val = train_test_split(test, test_size=0.5, random_state=123)

    for file_path_train in [os.path.join(i, j) for j in train]:
        dict_file['train'].append([file_path_train, idxnew, i])
    for file_path_test in [os.path.join(i, j) for j in test_new]:
        dict_file['test'].append([file_path_test, idxnew, i])
    for file_path_val in [os.path.join(i, j) for j in val]:
        dict_file['val'].append([file_path_val, idxnew, i])
    idxnew += 1

# %%
dict_file
# Out:
# {'train': [['travel/fdb74d9f.png', 0, 'travel'],
#   ['travel/0c54a462.png', 0, 'travel'],
#   ['travel/c359f3fa.png', 0, 'travel'],
#   ['travel/6b3ef934.png', 0, 'travel'],
#   ['travel/c348796c.png', 0, 'travel'],
#   ['travel/7ab91a58.png', 0, 'travel'],
#   ['travel/f5d7f758.png', 0, 'travel'],
#   ['travel/2f9fa6de.png', 0, 'travel'],
#   ['travel/f4c64c60.png', 0, 'travel'],
#   ['travel/251dccbe.png', 0, 'travel'],
#   ['travel/c39c70a5.png', 0, 'travel'],
#   ['travel/486371d4.png', 0, 'travel'],
#   ['travel/3fb23a83.png', 0, 'travel'],
#   ['beauty-and-grooming/c0e07dbc.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/a5742969.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/c0ab370a.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/417668cb.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/f9016593.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/6001acd7.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/35b81949.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/66de2113.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/7b227ef0.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/21e27cc4.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/6699b657.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/4a22b26f.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/298cc3a6.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/b7a5cbca.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/4569b568.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/0d146f40.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/391734a2.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/99cf7058.png', 1, 'beauty-and-grooming'],
#   ['adventure/e8a578f7.png', 2, 'adventure'],
#   ['adventure/6ffbbf68.png', 2, 'adventure'],
#   ['adventure/229fe675.png', 2, 'adventure'],
#   ['adventure/df52fe10.png', 2, 'adventure'],
#   ['adventure/1b5e176e.png', 2, 'adventure'],
#   ['animals/5fa7f0bb.png', 3, 'animals'],
#   ['animals/692a914b.png', 3, 'animals'],
#   ['animals/dbc6933f.png', 3, 'animals'],
#   ['animals/5a2e12fd.png', 3, 'animals'],
#   ['animals/89dec2a7.png', 3, 'animals'],
#   ['animals/abd228cc.png', 3, 'animals'],
#   ['animals/2caf89f3.png', 3, 'animals'],
#   ['animals/2aa55d76.png', 3, 'animals'],
#   ['animals/edf06d66.png', 3, 'animals'],
#   ['animals/a5784648.png', 3, 'animals'],
#   ['animals/09baffdb.png', 3, 'animals'],
#   ['fashion/ae45f19a.png', 4, 'fashion'],
#   ['fashion/249ce202.png', 4, 'fashion'],
#   ['fashion/c6b599b8.png', 4, 'fashion'],
#   ['fashion/823c2c1a.png', 4, 'fashion'],
#   ['fashion/e53aca60.png', 4, 'fashion'],
#   ['fashion/716b58ee.png', 4, 'fashion'],
#   ['fashion/50a60e50.png', 4, 'fashion'],
#   ['fashion/ca61c3fd.png', 4, 'fashion'],
#   ['fashion/cad76a45.png', 4, 'fashion'],
#   ['fashion/3651c1a2.png', 4, 'fashion'],
#   ['fashion/3fe1725c.png', 4, 'fashion'],
#   ['fashion/24951366.png', 4, 'fashion'],
#   ['fashion/d034fe37.png', 4, 'fashion'],
#   ['fashion/7144db67.png', 4, 'fashion'],
#   ['fashion/287f87c2.png', 4, 'fashion'],
#   ['fashion/45ca3418.png', 4, 'fashion'],
#   ['fashion/d946fa87.png', 4, 'fashion'],
#   ['fashion/11654adc.png', 4, 'fashion'],
#   ['fashion/9c9f813a.png', 4, 'fashion'],
#   ['fashion/7a2d8037.png', 4, 'fashion'],
#   ['fashion/0d00f941.png', 4, 'fashion'],
#   ['fashion/3a963db5.png', 4, 'fashion'],
#   ['fashion/ea9234bd.png', 4, 'fashion'],
#   ['fashion/2f1135a6.png', 4, 'fashion'],
#   ['fashion/f6c12aad.png', 4, 'fashion'],
#   ['fashion/031ea645.png', 4, 'fashion'],
#   ['family-and-friends/38d58174.png', 5, 'family-and-friends'],
#   ['family-and-friends/15083eef.png', 5, 'family-and-friends'],
#   ['family-and-friends/629871eb.png', 5, 'family-and-friends'],
#   ['family-and-friends/a213323b.png', 5, 'family-and-friends'],
#   ['family-and-friends/957571fa.png', 5, 'family-and-friends'],
#   ['family-and-friends/66281d15.png', 5, 'family-and-friends'],
#   ['family-and-friends/55321608.png', 5, 'family-and-friends'],
#   ['family-and-friends/cc2f94bf.png', 5, 'family-and-friends'],
#   ['family-and-friends/f67095a4.png', 5, 'family-and-friends'],
#   ['family-and-friends/3405f3eb.png', 5, 'family-and-friends'],
#   ['family-and-friends/76b49c5c.png', 5, 'family-and-friends'],
#   ['family-and-friends/d4000b7e.png', 5, 'family-and-friends'],
#   ['family-and-friends/8288504e.png', 5, 'family-and-friends'],
#   ['family-and-friends/abedc180.png', 5, 'family-and-friends'],
#   ['family-and-friends/be79949d.png', 5, 'family-and-friends'],
#   ['family-and-friends/b5b373d1.png', 5, 'family-and-friends'],
#   ['family-and-friends/eb30fa63.png', 5, 'family-and-friends'],
#   ['family-and-friends/d8fc60d1.png', 5, 'family-and-friends'],
#   ['family-and-friends/f6873a81.png', 5, 'family-and-friends'],
#   ['family-and-friends/09d442b3.png', 5, 'family-and-friends'],
#   ['family-and-friends/0cbfebc4.png', 5, 'family-and-friends'],
#   ['family-and-friends/f9ebdffa.png', 5, 'family-and-friends'],
#   ['family-and-friends/f1062a69.png', 5, 'family-and-friends'],
#   ['family-and-friends/686c93b4.png', 5, 'family-and-friends'],
#   ['family-and-friends/171c40d3.png', 5, 'family-and-friends'],
#   ['family-and-friends/d8320b81.png', 5, 'family-and-friends'],
#   ['family-and-friends/f9549c38.png', 5, 'family-and-friends'],
#   ['family-and-friends/34a560ca.png', 5, 'family-and-friends'],
#   ['family-and-friends/1856e636.png', 5, 'family-and-friends'],
#   ['family-and-friends/35d410bc.png', 5, 'family-and-friends'],
#   ['family-and-friends/c574b806.png', 5, 'family-and-friends'],
#   ['family-and-friends/51c083a0.png', 5, 'family-and-friends'],
#   ['family-and-friends/c377eb1e.png', 5, 'family-and-friends'],
#   ['family-and-friends/d51b8d71.png', 5, 'family-and-friends'],
#   ['family-and-friends/6e3a23d5.png', 5, 'family-and-friends'],
#   ['family-and-friends/02d2f82d.png', 5, 'family-and-friends'],
#   ['art-and-creativity/b99a2bbc.png', 6, 'art-and-creativity'],
#   ['art-and-creativity/fdd46bbb.png', 6, 'art-and-creativity'],
#   ['art-and-creativity/7679fd73.png', 6, 'art-and-creativity'],
#   ['food/212ce3bf.png', 7, 'food'],
#   ['food/218f9c5d.png', 7, 'food'],
#   ['food/7252b807.png', 7, 'food'],
#   ['food/95a7c025.png', 7, 'food'],
#   ['food/73f1f723.png', 7, 'food'],
#   ['food/773b1950.png', 7, 'food'],
#   ['food/b07aeaaf.png', 7, 'food'],
#   ['food/f3ce0c8c.png', 7, 'food'],
#   ['food/2f258899.png', 7, 'food'],
#   ['food/703dbc11.png', 7, 'food'],
#   ['food/c4bb842a.png', 7, 'food'],
#   ['food/bed18f64.png', 7, 'food'],
#   ['food/393e413a.png', 7, 'food'],
#   ['food/3c2eecc9.png', 7, 'food'],
#   ['food/395252c7.png', 7, 'food'],
#   ['food/0ccb7470.png', 7, 'food'],
#   ['food/e6f60089.png', 7, 'food'],
#   ['food/9318e4a7.png', 7, 'food'],
#   ['food/0a90dec8.png', 7, 'food'],
#   ['food/f7060892.png', 7, 'food'],
#   ['food/bc59191b.png', 7, 'food'],
#   ['food/4186433b.png', 7, 'food'],
#   ['food/c9399684.png', 7, 'food'],
#   ['food/074852e5.png', 7, 'food'],
#   ['food/3d82417b.png', 7, 'food'],
#   ['food/b5ccc969.png', 7, 'food'],
#   ['food/61fb10b6.png', 7, 'food'],
#   ['food/398f2c8f.png', 7, 'food'],
#   ['food/45259c4f.png', 7, 'food'],
#   ['food/63da24a4.png', 7, 'food'],
#   ['food/95df889e.png', 7, 'food'],
#   ['dance/6d558328.png', 8, 'dance'],
#   ['entertainment/e0f3dcf9.png', 9, 'entertainment'],
#   ['entertainment/c477426e.png', 9, 'entertainment'],
#   ['entertainment/a466c118.png', 9, 'entertainment'],
#   ['entertainment/7090d9ba.png', 9, 'entertainment'],
#   ['entertainment/8fcb18bd.png', 9, 'entertainment']],
#  'test': [['travel/ba127d9a.png', 0, 'travel'],
#   ['travel/e37c22a5.png', 0, 'travel'],
#   ['travel/32e362e2.png', 0, 'travel'],
#   ['travel/a5e29fef.png', 0, 'travel'],
#   ['travel/0d00e8aa.png', 0, 'travel'],
#   ['travel/6dbd206e.png', 0, 'travel'],
#   ['travel/ae3025c1.png', 0, 'travel'],
#   ['travel/c4b79f52.png', 0, 'travel'],
#   ['travel/b16836b3.png', 0, 'travel'],
#   ['travel/3c872ede.png', 0, 'travel'],
#   ['travel/107b785a.png', 0, 'travel'],
#   ['travel/611d641a.png', 0, 'travel'],
#   ['travel/93a838d3.png', 0, 'travel'],
#   ['travel/6dbe51b2.png', 0, 'travel'],
#   ['travel/1d89b092.png', 0, 'travel'],
#   ['travel/a1c8346c.png', 0, 'travel'],
#   ['travel/1989de4b.png', 0, 'travel'],
#   ['travel/4fcc7c69.png', 0, 'travel'],
#   ['travel/e324569e.png', 0, 'travel'],
#   ['travel/dea3e42c.png', 0, 'travel'],
#   ['travel/bdcf3acf.png', 0, 'travel'],
#   ['travel/54c3e8d0.png', 0, 'travel'],
#   ['travel/2b3dcb79.png', 0, 'travel'],
#   ['travel/7238b7f1.png', 0, 'travel'],
#   ['travel/d23069f0.png', 0, 'travel'],
#   ['travel/20e2e4f7.png', 0, 'travel'],
#   ['travel/3fbf81ef.png', 0, 'travel'],
#   ['beauty-and-grooming/4a5d1867.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/638c70e4.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/6ae7f2fe.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/1756efe1.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/11d49b7a.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/73966e3b.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/f5482357.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/81c9a351.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/821b835f.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/cedcd692.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/20d5c76c.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/e562d041.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/a0e2b8d4.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/d1fda065.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/feb8e4d7.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/b7f44256.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/e2ca07c7.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/e2eeb784.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/7975c7bc.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/bb82284c.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/c3b4d0b9.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/3048f202.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/bfcc8511.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/f7c0fcae.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/53d6492e.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/800064ba.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/85bbe379.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/9560d060.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/1e74bc45.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/597a154f.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/de262db7.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/1984c2ff.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/a16c769d.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/6beda504.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/9a9f3c39.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/9024dcca.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/36a511b1.png', 1, 'beauty-and-grooming'],
#   ['adventure/510c15f1.png', 2, 'adventure'],
#   ['adventure/14e5c3a0.png', 2, 'adventure'],
#   ['adventure/f2864cfd.png', 2, 'adventure'],
#   ['adventure/f889155e.png', 2, 'adventure'],
#   ['adventure/3ff184c0.png', 2, 'adventure'],
#   ['adventure/eec78f62.png', 2, 'adventure'],
#   ['adventure/7fdfa80a.png', 2, 'adventure'],
#   ['adventure/9db46a5b.png', 2, 'adventure'],
#   ['adventure/8f4536b6.png', 2, 'adventure'],
#   ['adventure/52059e81.png', 2, 'adventure'],
#   ['adventure/a2280e20.png', 2, 'adventure'],
#   ['adventure/c1cdf374.png', 2, 'adventure'],
#   ['animals/bfd7c672.png', 3, 'animals'],
#   ['animals/a7b8e705.png', 3, 'animals'],
#   ['animals/cc32ad09.png', 3, 'animals'],
#   ['animals/67322ee0.png', 3, 'animals'],
#   ['animals/4c5c05eb.png', 3, 'animals'],
#   ['animals/16847d2a.png', 3, 'animals'],
#   ['animals/37aa4ccb.png', 3, 'animals'],
#   ['animals/b3cff041.png', 3, 'animals'],
#   ['animals/2c6aa68b.png', 3, 'animals'],
#   ['animals/cb980e3f.png', 3, 'animals'],
#   ['animals/5f91c4b6.png', 3, 'animals'],
#   ['animals/6ef05029.png', 3, 'animals'],
#   ['animals/155791bb.png', 3, 'animals'],
#   ['animals/b846b576.png', 3, 'animals'],
#   ['animals/0a3700c9.png', 3, 'animals'],
#   ['animals/86bf4f16.png', 3, 'animals'],
#   ['animals/ea1779d0.png', 3, 'animals'],
#   ['animals/f34ba663.png', 3, 'animals'],
#   ['animals/b6b43ce7.png', 3, 'animals'],
#   ['animals/896d5733.png', 3, 'animals'],
#   ['animals/035a07f4.png', 3, 'animals'],
#   ['animals/6840d581.png', 3, 'animals'],
#   ['fashion/c1684183.png', 4, 'fashion'],
#   ['fashion/0b1e5acc.png', 4, 'fashion'],
#   ['fashion/d0d68bf5.png', 4, 'fashion'],
#   ['fashion/e7e99bfb.png', 4, 'fashion'],
#   ['fashion/7a9d6831.png', 4, 'fashion'],
#   ['fashion/a9275a42.png', 4, 'fashion'],
#   ['fashion/a47b8d45.png', 4, 'fashion'],
#   ['fashion/2822c7b4.png', 4, 'fashion'],
#   ['fashion/a68f5c2f.png', 4, 'fashion'],
#   ['fashion/409aaa59.png', 4, 'fashion'],
#   ['fashion/b004433e.png', 4, 'fashion'],
#   ['fashion/9ab7118d.png', 4, 'fashion'],
#   ['fashion/d320d732.png', 4, 'fashion'],
#   ['fashion/5e11a5ac.png', 4, 'fashion'],
#   ['fashion/bb5791ba.png', 4, 'fashion'],
#   ['fashion/f96ce10c.png', 4, 'fashion'],
#   ['fashion/40522da2.png', 4, 'fashion'],
#   ['fashion/75f370a0.png', 4, 'fashion'],
#   ['fashion/df6fc80f.png', 4, 'fashion'],
#   ['fashion/21f6c9dc.png', 4, 'fashion'],
#   ['fashion/925fbfb1.png', 4, 'fashion'],
#   ['fashion/7e5dcf7b.png', 4, 'fashion'],
#   ['fashion/841855b5.png', 4, 'fashion'],
#   ['fashion/49715435.png', 4, 'fashion'],
#   ['fashion/05bf2027.png', 4, 'fashion'],
#   ['fashion/ac8c06f1.png', 4, 'fashion'],
#   ['fashion/e2c23090.png', 4, 'fashion'],
#   ['fashion/87fb1b51.png', 4, 'fashion'],
#   ['fashion/2ce9556b.png', 4, 'fashion'],
#   ['fashion/d269a1a8.png', 4, 'fashion'],
#   ['fashion/93495675.png', 4, 'fashion'],
#   ['fashion/7715d750.png', 4, 'fashion'],
#   ['fashion/9a32ff85.png', 4, 'fashion'],
#   ['fashion/cd4b7bcf.png', 4, 'fashion'],
#   ['fashion/9e56b594.png', 4, 'fashion'],
#   ['fashion/d7240468.png', 4, 'fashion'],
#   ['fashion/ac7d3537.png', 4, 'fashion'],
#   ['fashion/92b84217.png', 4, 'fashion'],
#   ['fashion/9b4f661f.png', 4, 'fashion'],
#   ['fashion/16e6dca1.png', 4, 'fashion'],
#   ['fashion/18ef33f5.png', 4, 'fashion'],
#   ['fashion/4004a992.png', 4, 'fashion'],
#   ['fashion/f49f55a8.png', 4, 'fashion'],
#   ['fashion/44c83c61.png', 4, 'fashion'],
#   ['fashion/6794ca5d.png', 4, 'fashion'],
#   ['fashion/e29e588e.png', 4, 'fashion'],
#   ['fashion/8765951f.png', 4, 'fashion'],
#   ['fashion/69dbb60a.png', 4, 'fashion'],
#   ['fashion/d3ecd149.png', 4, 'fashion'],
#   ['fashion/8a25d753.png', 4, 'fashion'],
#   ['fashion/c069d808.png', 4, 'fashion'],
#   ['fashion/35efab4b.png', 4, 'fashion'],
#   ['family-and-friends/5cb7cb0b.png', 5, 'family-and-friends'],
#   ['family-and-friends/8bcb50c0.png', 5, 'family-and-friends'],
#   ['family-and-friends/d092d8c3.png', 5, 'family-and-friends'],
#   ['family-and-friends/6d407c45.png', 5, 'family-and-friends'],
#   ['family-and-friends/c1404e9b.png', 5, 'family-and-friends'],
#   ['family-and-friends/bb327f8d.png', 5, 'family-and-friends'],
#   ['family-and-friends/d9f4748b.png', 5, 'family-and-friends'],
#   ['family-and-friends/8fbcc53c.png', 5, 'family-and-friends'],
#   ['family-and-friends/3a6d628b.png', 5, 'family-and-friends'],
#   ['family-and-friends/1b044dab.png', 5, 'family-and-friends'],
#   ['family-and-friends/a09fe464.png', 5, 'family-and-friends'],
#   ['family-and-friends/1781d33f.png', 5, 'family-and-friends'],
#   ['family-and-friends/80b3b03a.png', 5, 'family-and-friends'],
#   ['family-and-friends/ab05bd47.png', 5, 'family-and-friends'],
#   ['family-and-friends/40005128.png', 5, 'family-and-friends'],
#   ['family-and-friends/172b230d.png', 5, 'family-and-friends'],
#   ['family-and-friends/2543d37f.png', 5, 'family-and-friends'],
#   ['family-and-friends/bd8fa77f.png', 5, 'family-and-friends'],
#   ['family-and-friends/cc953001.png', 5, 'family-and-friends'],
#   ['family-and-friends/299e240b.png', 5, 'family-and-friends'],
#   ['family-and-friends/4aa10fd2.png', 5, 'family-and-friends'],
#   ['family-and-friends/3c4f7a89.png', 5, 'family-and-friends'],
#   ['family-and-friends/2a99f298.png', 5, 'family-and-friends'],
#   ['family-and-friends/dbc17b3b.png', 5, 'family-and-friends'],
#   ['family-and-friends/32553751.png', 5, 'family-and-friends'],
#   ['family-and-friends/b085e1dd.png', 5, 'family-and-friends'],
#   ['family-and-friends/2c6c7e93.png', 5, 'family-and-friends'],
#   ['family-and-friends/2be9ef3e.png', 5, 'family-and-friends'],
#   ['family-and-friends/6931cce3.png', 5, 'family-and-friends'],
#   ['family-and-friends/20b7aa65.png', 5, 'family-and-friends'],
#   ['family-and-friends/d192f052.png', 5, 'family-and-friends'],
#   ['family-and-friends/c645d189.png', 5, 'family-and-friends'],
#   ['family-and-friends/f4801239.png', 5, 'family-and-friends'],
#   ['family-and-friends/80826d9f.png', 5, 'family-and-friends'],
#   ['family-and-friends/d4c43521.png', 5, 'family-and-friends'],
#   ['family-and-friends/79a32714.png', 5, 'family-and-friends'],
#   ['family-and-friends/b37ab0b5.png', 5, 'family-and-friends'],
#   ['family-and-friends/32000e6c.png', 5, 'family-and-friends'],
#   ['family-and-friends/e55de511.png', 5, 'family-and-friends'],
#   ['family-and-friends/9a992897.png', 5, 'family-and-friends'],
#   ['family-and-friends/9e737041.png', 5, 'family-and-friends'],
#   ['family-and-friends/cba75e7d.png', 5, 'family-and-friends'],
#   ['family-and-friends/4ebd4373.png', 5, 'family-and-friends'],
#   ['family-and-friends/fcc0a843.png', 5, 'family-and-friends'],
#   ['family-and-friends/c12edc2c.png', 5, 'family-and-friends'],
#   ['family-and-friends/fd2ed31f.png', 5, 'family-and-friends'],
#   ['family-and-friends/74e27eea.png', 5, 'family-and-friends'],
#   ['family-and-friends/14b86895.png', 5, 'family-and-friends'],
#   ['family-and-friends/c8bc500b.png', 5, 'family-and-friends'],
#   ['family-and-friends/120fe046.png', 5, 'family-and-friends'],
#   ['family-and-friends/33d8dbbf.png', 5, 'family-and-friends'],
#   ['family-and-friends/533b6718.png', 5, 'family-and-friends'],
#   ['family-and-friends/19b1b0bc.png', 5, 'family-and-friends'],
#   ['family-and-friends/f3da0992.png', 5, 'family-and-friends'],
#   ['family-and-friends/bae84cd8.png', 5, 'family-and-friends'],
#   ['family-and-friends/7fc20361.png', 5, 'family-and-friends'],
#   ['family-and-friends/c1f702e1.png', 5, 'family-and-friends'],
#   ['family-and-friends/f41b3561.png', 5, 'family-and-friends'],
#   ['family-and-friends/08eb697a.png', 5, 'family-and-friends'],
#   ['family-and-friends/6cda90a1.png', 5, 'family-and-friends'],
#   ['family-and-friends/52d8b255.png', 5, 'family-and-friends'],
#   ['family-and-friends/6f4e5c2a.png', 5, 'family-and-friends'],
#   ['family-and-friends/21bb285d.png', 5, 'family-and-friends'],
#   ['family-and-friends/658081ae.png', 5, 'family-and-friends'],
#   ['family-and-friends/6cd1d0bf.png', 5, 'family-and-friends'],
#   ['family-and-friends/8aa61db1.png', 5, 'family-and-friends'],
#   ['family-and-friends/c6eb2185.png', 5, 'family-and-friends'],
#   ['family-and-friends/078ef82b.png', 5, 'family-and-friends'],
#   ['family-and-friends/975f92d1.png', 5, 'family-and-friends'],
#   ['family-and-friends/7c423cdb.png', 5, 'family-and-friends'],
#   ['family-and-friends/16ee43d3.png', 5, 'family-and-friends'],
#   ['family-and-friends/018dd4c1.png', 5, 'family-and-friends'],
#   ['art-and-creativity/8b969c76.png', 6, 'art-and-creativity'],
#   ['art-and-creativity/5a9a8025.png', 6, 'art-and-creativity'],
#   ['art-and-creativity/3db26d50.png', 6, 'art-and-creativity'],
#   ['art-and-creativity/48e21d76.png', 6, 'art-and-creativity'],
#   ['art-and-creativity/ea6e03f8.png', 6, 'art-and-creativity'],
#   ['art-and-creativity/00dbb521.png', 6, 'art-and-creativity'],
#   ['food/7465be14.png', 7, 'food'],
#   ['food/a57bd36c.png', 7, 'food'],
#   ['food/32957563.png', 7, 'food'],
#   ['food/90807db4.png', 7, 'food'],
#   ['food/33cf0a2c.png', 7, 'food'],
#   ['food/02d9b133.png', 7, 'food'],
#   ['food/526b7e33.png', 7, 'food'],
#   ['food/853109fa.png', 7, 'food'],
#   ['food/ee3ad0e4.png', 7, 'food'],
#   ['food/822def9d.png', 7, 'food'],
#   ['food/931bd278.png', 7, 'food'],
#   ['food/0b6c1016.png', 7, 'food'],
#   ['food/ec7a0177.png', 7, 'food'],
#   ['food/6ac02be1.png', 7, 'food'],
#   ['food/469e50d9.png', 7, 'food'],
#   ['food/d4e9e223.png', 7, 'food'],
#   ['food/7d656e32.png', 7, 'food'],
#   ['food/bc70d09c.png', 7, 'food'],
#   ['food/c5e0eed8.png', 7, 'food'],
#   ['food/ad76aa0c.png', 7, 'food'],
#   ['food/29135930.png', 7, 'food'],
#   ['food/fc4dfe68.png', 7, 'food'],
#   ['food/d5cd5bed.png', 7, 'food'],
#   ['food/5049ab18.png', 7, 'food'],
#   ['food/63a92d20.png', 7, 'food'],
#   ['food/b4f8e8d0.png', 7, 'food'],
#   ['food/616896d5.png', 7, 'food'],
#   ['food/099d211d.png', 7, 'food'],
#   ['food/15b4cff0.png', 7, 'food'],
#   ['food/26738831.png', 7, 'food'],
#   ['food/b88fa773.png', 7, 'food'],
#   ['food/27bb3bb0.png', 7, 'food'],
#   ['food/af78050d.png', 7, 'food'],
#   ['food/35587c92.png', 7, 'food'],
#   ['food/93db7927.png', 7, 'food'],
#   ['food/a0f320be.png', 7, 'food'],
#   ['food/c52072c8.png', 7, 'food'],
#   ['food/fe405450.png', 7, 'food'],
#   ['food/349b0987.png', 7, 'food'],
#   ['food/1bf1adab.png', 7, 'food'],
#   ['food/6d565078.png', 7, 'food'],
#   ['food/b5bd6983.png', 7, 'food'],
#   ['food/b4e55423.png', 7, 'food'],
#   ['food/b7355755.png', 7, 'food'],
#   ['food/07337453.png', 7, 'food'],
#   ['food/79e5526a.png', 7, 'food'],
#   ['food/72dd9164.png', 7, 'food'],
#   ['food/9974bf63.png', 7, 'food'],
#   ['food/fa743c50.png', 7, 'food'],
#   ['food/54ae6b80.png', 7, 'food'],
#   ['food/b3445234.png', 7, 'food'],
#   ['food/4097324d.png', 7, 'food'],
#   ['food/7daf6dad.png', 7, 'food'],
#   ['food/c3481831.png', 7, 'food'],
#   ['food/259ff17d.png', 7, 'food'],
#   ['food/d31e08c4.png', 7, 'food'],
#   ['food/f75c2805.png', 7, 'food'],
#   ['food/3bdd6e97.png', 7, 'food'],
#   ['food/d6a6959f.png', 7, 'food'],
#   ['food/27512f9d.png', 7, 'food'],
#   ['food/00d751f9.png', 7, 'food'],
#   ['food/ebc966a6.png', 7, 'food'],
#   ['dance/92cd1162.png', 8, 'dance'],
#   ['dance/8aa76fd6.png', 8, 'dance'],
#   ['dance/1892f65a.png', 8, 'dance'],
#   ['entertainment/68c26c6e.png', 9, 'entertainment'],
#   ['entertainment/ee37f673.png', 9, 'entertainment'],
#   ['entertainment/032c1638.png', 9, 'entertainment'],
#   ['entertainment/735a7884.png', 9, 'entertainment'],
#   ['entertainment/752b6570.png', 9, 'entertainment'],
#   ['entertainment/da309d32.png', 9, 'entertainment'],
#   ['entertainment/fa38b9cc.png', 9, 'entertainment'],
#   ['entertainment/891eb2e1.png', 9, 'entertainment'],
#   ['entertainment/33aab4db.png', 9, 'entertainment'],
#   ['entertainment/c2a1e255.png', 9, 'entertainment']],
#  'val': [['travel/49e7fdef.png', 0, 'travel'],
#   ['travel/bd8d612e.png', 0, 'travel'],
#   ['travel/89b8a3d1.png', 0, 'travel'],
#   ['travel/3c86bcca.png', 0, 'travel'],
#   ['travel/2b18125c.png', 0, 'travel'],
#   ['travel/4e191b39.png', 0, 'travel'],
#   ['travel/dac38926.png', 0, 'travel'],
#   ['travel/661af3dd.png', 0, 'travel'],
#   ['travel/aed9d7e8.png', 0, 'travel'],
#   ['travel/205ae094.png', 0, 'travel'],
#   ['travel/e658e1c8.png', 0, 'travel'],
#   ['travel/b0c65ed7.png', 0, 'travel'],
#   ['travel/ee364a30.png', 0, 'travel'],
#   ['travel/ca96eafb.png', 0, 'travel'],
#   ['travel/3a97e130.png', 0, 'travel'],
#   ['travel/8377400d.png', 0, 'travel'],
#   ['travel/2d749c70.png', 0, 'travel'],
#   ['travel/f4e7a9f1.png', 0, 'travel'],
#   ['travel/9fd2f599.png', 0, 'travel'],
#   ['travel/f8d4d1a6.png', 0, 'travel'],
#   ['travel/1721e87f.png', 0, 'travel'],
#   ['travel/1f468a8a.png', 0, 'travel'],
#   ['travel/dd97967d.png', 0, 'travel'],
#   ['travel/cc687e7a.png', 0, 'travel'],
#   ['travel/de69ba30.png', 0, 'travel'],
#   ['travel/2047f996.png', 0, 'travel'],
#   ['travel/b5c9459e.png', 0, 'travel'],
#   ['travel/32cd5733.png', 0, 'travel'],
#   ['beauty-and-grooming/8372de0c.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/9c73106f.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/5ca3cd0a.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/13c8dd5d.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/ac5a0faf.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/2b5fe586.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/2c49fdc2.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/706dd08c.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/d34792fe.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/dd3543e9.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/ace2b63e.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/a4e4e642.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/ddd55e64.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/7b3468fe.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/a56d9e16.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/129e7d52.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/4356aab7.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/d3b5a821.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/ed362578.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/c710bf19.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/9a6cfbf1.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/e7e7b7a2.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/494d2db0.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/375febf7.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/83ba519c.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/3be79dd5.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/5feed5c0.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/e967ebee.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/4d507562.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/d14a3706.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/786e0755.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/83a00714.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/0f6177cd.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/7167b0c1.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/12a356d3.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/762d8408.png', 1, 'beauty-and-grooming'],
#   ['beauty-and-grooming/61d37727.png', 1, 'beauty-and-grooming'],
#   ['adventure/92171fde.png', 2, 'adventure'],
#   ['adventure/7aaabe06.png', 2, 'adventure'],
#   ['adventure/ba32fd42.png', 2, 'adventure'],
#   ['adventure/8746c8c4.png', 2, 'adventure'],
#   ['adventure/751d38bd.png', 2, 'adventure'],
#   ['adventure/f594dfa8.png', 2, 'adventure'],
#   ['adventure/ec921761.png', 2, 'adventure'],
#   ['adventure/ba15b783.png', 2, 'adventure'],
#   ['adventure/1dccdf9a.png', 2, 'adventure'],
#   ['adventure/51832ece.png', 2, 'adventure'],
#   ['adventure/29f923e6.png', 2, 'adventure'],
#   ['adventure/6f28b96f.png', 2, 'adventure'],
#   ['animals/24a23354.png', 3, 'animals'],
#   ['animals/82a1d5fb.png', 3, 'animals'],
#   ['animals/eae1e53a.png', 3, 'animals'],
#   ['animals/29fd084e.png', 3, 'animals'],
#   ['animals/f52529ac.png', 3, 'animals'],
#   ['animals/8cbbd721.png', 3, 'animals'],
#   ['animals/c737492c.png', 3, 'animals'],
#   ['animals/c9f0a824.png', 3, 'animals'],
#   ['animals/381b5286.png', 3, 'animals'],
#   ['animals/85be221a.png', 3, 'animals'],
#   ['animals/e5771be2.png', 3, 'animals'],
#   ['animals/01544c00.png', 3, 'animals'],
#   ['animals/acc2d6ee.png', 3, 'animals'],
#   ['animals/71194461.png', 3, 'animals'],
#   ['animals/c0ae0226.png', 3, 'animals'],
#   ['animals/9c3159ea.png', 3, 'animals'],
#   ['animals/5bb15617.png', 3, 'animals'],
#   ['animals/6263d6d3.png', 3, 'animals'],
#   ['animals/463e1082.png', 3, 'animals'],
#   ['animals/c264c38f.png', 3, 'animals'],
#   ['animals/0d2d29d4.png', 3, 'animals'],
#   ['animals/d190bf86.png', 3, 'animals'],
#   ['animals/507b0da3.png', 3, 'animals'],
#   ['fashion/26f35f09.png', 4, 'fashion'],
#   ['fashion/7029cd66.png', 4, 'fashion'],
#   ['fashion/bee94c26.png', 4, 'fashion'],
#   ['fashion/f8ef6a2c.png', 4, 'fashion'],
#   ['fashion/fd2a47e9.png', 4, 'fashion'],
#   ['fashion/ffe19615.png', 4, 'fashion'],
#   ['fashion/44f33f72.png', 4, 'fashion'],
#   ['fashion/33fbf28a.png', 4, 'fashion'],
#   ['fashion/0dbc13d7.png', 4, 'fashion'],
#   ['fashion/cedae05c.png', 4, 'fashion'],
#   ['fashion/a875cc92.png', 4, 'fashion'],
#   ['fashion/4cf39b6f.png', 4, 'fashion'],
#   ['fashion/5085d14b.png', 4, 'fashion'],
#   ['fashion/64d55208.png', 4, 'fashion'],
#   ['fashion/0feaeaaf.png', 4, 'fashion'],
#   ['fashion/128fe154.png', 4, 'fashion'],
#   ['fashion/f129521a.png', 4, 'fashion'],
#   ['fashion/98f8d7bd.png', 4, 'fashion'],
#   ['fashion/ae1f8b2c.png', 4, 'fashion'],
#   ['fashion/5a001d6f.png', 4, 'fashion'],
#   ['fashion/73b80add.png', 4, 'fashion'],
#   ['fashion/815a18d6.png', 4, 'fashion'],
#   ['fashion/5800dd01.png', 4, 'fashion'],
#   ['fashion/4c31be1c.png', 4, 'fashion'],
#   ['fashion/8e8f7051.png', 4, 'fashion'],
#   ['fashion/4e1ea7d2.png', 4, 'fashion'],
#   ['fashion/5e72840a.png', 4, 'fashion'],
#   ['fashion/86a04b60.png', 4, 'fashion'],
#   ['fashion/426aa181.png', 4, 'fashion'],
#   ['fashion/f37ef20d.png', 4, 'fashion'],
#   ['fashion/9c7714d3.png', 4, 'fashion'],
#   ['fashion/1b5930c5.png', 4, 'fashion'],
#   ['fashion/abd46661.png', 4, 'fashion'],
#   ['fashion/40983dd0.png', 4, 'fashion'],
#   ['fashion/8762a325.png', 4, 'fashion'],
#   ['fashion/e63299f2.png', 4, 'fashion'],
#   ['fashion/539de031.png', 4, 'fashion'],
#   ['fashion/57d35b9b.png', 4, 'fashion'],
#   ['fashion/5d3cf25a.png', 4, 'fashion'],
#   ['fashion/0335baef.png', 4, 'fashion'],
#   ['fashion/d64ed0ce.png', 4, 'fashion'],
#   ['fashion/f5d20381.png', 4, 'fashion'],
#   ['fashion/8fa3fb10.png', 4, 'fashion'],
#   ['fashion/2a6a4451.png', 4, 'fashion'],
#   ['fashion/2c37bd11.png', 4, 'fashion'],
#   ['fashion/35737f65.png', 4, 'fashion'],
#   ['fashion/5b0eadd7.png', 4, 'fashion'],
#   ['fashion/8a0d2747.png', 4, 'fashion'],
#   ['fashion/64a38743.png', 4, 'fashion'],
#   ['fashion/f0bdc296.png', 4, 'fashion'],
#   ['fashion/f7c62a68.png', 4, 'fashion'],
#   ['fashion/ea7bb6e9.png', 4, 'fashion'],
#   ['fashion/61b6542b.png', 4, 'fashion'],
#   ['family-and-friends/cddbcf84.png', 5, 'family-and-friends'],
#   ['family-and-friends/bc70d531.png', 5, 'family-and-friends'],
#   ['family-and-friends/ee70f35d.png', 5, 'family-and-friends'],
#   ['family-and-friends/47d46b31.png', 5, 'family-and-friends'],
#   ['family-and-friends/212303e5.png', 5, 'family-and-friends'],
#   ['family-and-friends/6bb2571d.png', 5, 'family-and-friends'],
#   ['family-and-friends/ea4750d5.png', 5, 'family-and-friends'],
#   ['family-and-friends/12dcadf1.png', 5, 'family-and-friends'],
#   ['family-and-friends/652c8cff.png', 5, 'family-and-friends'],
#   ['family-and-friends/c69ff0d4.png', 5, 'family-and-friends'],
#   ['family-and-friends/06fde5f6.png', 5, 'family-and-friends'],
#   ['family-and-friends/42a0f322.png', 5, 'family-and-friends'],
#   ['family-and-friends/5132cd5e.png', 5, 'family-and-friends'],
#   ['family-and-friends/7f505282.png', 5, 'family-and-friends'],
#   ['family-and-friends/479c6fdb.png', 5, 'family-and-friends'],
#   ['family-and-friends/59420ee0.png', 5, 'family-and-friends'],
#   ['family-and-friends/c35516f1.png', 5, 'family-and-friends'],
#   ['family-and-friends/f2f37408.png', 5, 'family-and-friends'],
#   ['family-and-friends/66e487ea.png', 5, 'family-and-friends'],
#   ['family-and-friends/562cbb96.png', 5, 'family-and-friends'],
#   ['family-and-friends/b1025283.png', 5, 'family-and-friends'],
#   ['family-and-friends/7296c092.png', 5, 'family-and-friends'],
#   ['family-and-friends/3482808c.png', 5, 'family-and-friends'],
#   ['family-and-friends/115a254a.png', 5, 'family-and-friends'],
#   ['family-and-friends/2b501766.png', 5, 'family-and-friends'],
#   ['family-and-friends/b9f1d02e.png', 5, 'family-and-friends'],
#   ['family-and-friends/333c1434.png', 5, 'family-and-friends'],
#   ['family-and-friends/f42f6c86.png', 5, 'family-and-friends'],
#   ['family-and-friends/98ee003d.png', 5, 'family-and-friends'],
#   ['family-and-friends/ba6b3f4f.png', 5, 'family-and-friends'],
#   ['family-and-friends/ec0e8ddd.png', 5, 'family-and-friends'],
#   ['family-and-friends/332ce4b9.png', 5, 'family-and-friends'],
#   ['family-and-friends/b1a10fb0.png', 5, 'family-and-friends'],
#   ['family-and-friends/b6f1115b.png', 5, 'family-and-friends'],
#   ['family-and-friends/2b41c0ce.png', 5, 'family-and-friends'],
#   ['family-and-friends/20b59bd5.png', 5, 'family-and-friends'],
#   ['family-and-friends/fe0da429.png', 5, 'family-and-friends'],
#   ['family-and-friends/ec2fc466.png', 5, 'family-and-friends'],
#   ['family-and-friends/ab5c4470.png', 5, 'family-and-friends'],
#   ['family-and-friends/e28230cb.png', 5, 'family-and-friends'],
#   ['family-and-friends/1556db44.png', 5, 'family-and-friends'],
#   ['family-and-friends/56c548e0.png', 5, 'family-and-friends'],
#   ['family-and-friends/730229f7.png', 5, 'family-and-friends'],
#   ['family-and-friends/1bc889cf.png', 5, 'family-and-friends'],
#   ['family-and-friends/a972cf77.png', 5, 'family-and-friends'],
#   ['family-and-friends/539047c9.png', 5, 'family-and-friends'],
#   ['family-and-friends/87e8c3fd.png', 5, 'family-and-friends'],
#   ['family-and-friends/18bd20f6.png', 5, 'family-and-friends'],
#   ['family-and-friends/d2189650.png', 5, 'family-and-friends'],
#   ['family-and-friends/e51f8596.png', 5, 'family-and-friends'],
#   ['family-and-friends/84d193e2.png', 5, 'family-and-friends'],
#   ['family-and-friends/6cc8e923.png', 5, 'family-and-friends'],
#   ['family-and-friends/44e14ded.png', 5, 'family-and-friends'],
#   ['family-and-friends/5b5ac081.png', 5, 'family-and-friends'],
#   ['family-and-friends/31a2fa4e.png', 5, 'family-and-friends'],
#   ['family-and-friends/9c919ace.png', 5, 'family-and-friends'],
#   ['family-and-friends/778caab9.png', 5, 'family-and-friends'],
#   ['family-and-friends/ef46316d.png', 5, 'family-and-friends'],
#   ['family-and-friends/5f6222bd.png', 5, 'family-and-friends'],
#   ['family-and-friends/ac42c8f7.png', 5, 'family-and-friends'],
#   ['family-and-friends/0c22697b.png', 5, 'family-and-friends'],
#   ['family-and-friends/77c649ab.png', 5, 'family-and-friends'],
#   ['family-and-friends/77fb2a4f.png', 5, 'family-and-friends'],
#   ['family-and-friends/96eb940e.png', 5, 'family-and-friends'],
#   ['family-and-friends/1f530b22.png', 5, 'family-and-friends'],
#   ['family-and-friends/1cb9ffab.png', 5, 'family-and-friends'],
#   ['family-and-friends/6bed23ea.png', 5, 'family-and-friends'],
#   ['family-and-friends/ef94d9b1.png', 5, 'family-and-friends'],
#   ['family-and-friends/0d409969.png', 5, 'family-and-friends'],
#   ['family-and-friends/908bf66e.png', 5, 'family-and-friends'],
#   ['family-and-friends/399c286e.png', 5, 'family-and-friends'],
#   ['family-and-friends/c4824f09.png', 5, 'family-and-friends'],
#   ['art-and-creativity/fb65d5a6.png', 6, 'art-and-creativity'],
#   ['art-and-creativity/8bab8036.png', 6, 'art-and-creativity'],
#   ['art-and-creativity/f028d29b.png', 6, 'art-and-creativity'],
#   ['art-and-creativity/4f10eb7e.png', 6, 'art-and-creativity'],
#   ['art-and-creativity/7bcdd11b.png', 6, 'art-and-creativity'],
#   ['art-and-creativity/2103dd51.png', 6, 'art-and-creativity'],
#   ['food/0ca48343.png', 7, 'food'],
#   ['food/9b8d7a69.png', 7, 'food'],
#   ['food/41f2e2cb.png', 7, 'food'],
#   ['food/31385840.png', 7, 'food'],
#   ['food/9cb15d58.png', 7, 'food'],
#   ['food/27c2643b.png', 7, 'food'],
#   ['food/4b0dde86.png', 7, 'food'],
#   ['food/5185b44c.png', 7, 'food'],
#   ['food/b2ba4a5e.png', 7, 'food'],
#   ['food/03c377f0.png', 7, 'food'],
#   ['food/77479cff.png', 7, 'food'],
#   ['food/1fa66e28.png', 7, 'food'],
#   ['food/fe141df1.png', 7, 'food'],
#   ['food/03dc3aed.png', 7, 'food'],
#   ['food/3857bf97.png', 7, 'food'],
#   ['food/9e3e4c1d.png', 7, 'food'],
#   ['food/0410f35c.png', 7, 'food'],
#   ['food/5e32dd30.png', 7, 'food'],
#   ['food/d84ba828.png', 7, 'food'],
#   ['food/4ab36e4e.png', 7, 'food'],
#   ['food/7cbdefca.png', 7, 'food'],
#   ['food/a0d64307.png', 7, 'food'],
#   ['food/597270d0.png', 7, 'food'],
#   ['food/19e7047d.png', 7, 'food'],
#   ['food/d769963c.png', 7, 'food'],
#   ['food/405d2deb.png', 7, 'food'],
#   ['food/c87b7c61.png', 7, 'food'],
#   ['food/0cf52bea.png', 7, 'food'],
#   ['food/7b81eafa.png', 7, 'food'],
#   ['food/4efb20f1.png', 7, 'food'],
#   ['food/a8566437.png', 7, 'food'],
#   ['food/2a934176.png', 7, 'food'],
#   ['food/0aefab49.png', 7, 'food'],
#   ['food/f0a7445a.png', 7, 'food'],
#   ['food/93eab432.png', 7, 'food'],
#   ['food/842e729e.png', 7, 'food'],
#   ['food/fbe10bea.png', 7, 'food'],
#   ['food/abf1ba29.png', 7, 'food'],
#   ['food/46dd5390.png', 7, 'food'],
#   ['food/dd885f09.png', 7, 'food'],
#   ['food/a1d08f21.png', 7, 'food'],
#   ['food/17af9f39.png', 7, 'food'],
#   ['food/faf89499.png', 7, 'food'],
#   ['food/5ff299ac.png', 7, 'food'],
#   ['food/85fb0d15.png', 7, 'food'],
#   ['food/7c85abe8.png', 7, 'food'],
#   ['food/eac13217.png', 7, 'food'],
#   ['food/fec0104e.png', 7, 'food'],
#   ['food/749cfbb4.png', 7, 'food'],
#   ['food/3fdab0eb.png', 7, 'food'],
#   ['food/0cbc7413.png', 7, 'food'],
#   ['food/e2926556.png', 7, 'food'],
#   ['food/e74ca068.png', 7, 'food'],
#   ['food/6bd82b41.png', 7, 'food'],
#   ['food/a78a35b4.png', 7, 'food'],
#   ['food/51f54679.png', 7, 'food'],
#   ['food/c9627ae8.png', 7, 'food'],
#   ['food/bbd74f13.png', 7, 'food'],
#   ['food/1ea3584d.png', 7, 'food'],
#   ['food/a839c537.png', 7, 'food'],
#   ['food/b822539b.png', 7, 'food'],
#   ['food/b1cd2c9c.png', 7, 'food'],
#   ['dance/6163ad20.png', 8, 'dance'],
#   ['dance/e4a77e85.png', 8, 'dance'],
#   ['dance/a49cd433.png', 8, 'dance'],
#   ['dance/30fe94b2.png', 8, 'dance'],
#   ['entertainment/4daa8c2f.png', 9, 'entertainment'],
#   ['entertainment/6b3377cf.png', 9, 'entertainment'],
#   ['entertainment/a58b8854.png', 9, 'entertainment'],
#   ['entertainment/398c9b72.png', 9, 'entertainment'],
#   ['entertainment/900d522e.png', 9, 'entertainment'],
#   ['entertainment/7f124b63.png', 9, 'entertainment'],
#   ['entertainment/ca5bbd1a.png', 9, 'entertainment'],
#   ['entertainment/0f1cf437.png', 9, 'entertainment'],
#   ['entertainment/1a1c76a1.png', 9, 'entertainment'],
#   ['entertainment/459780b6.png', 9, 'entertainment'],
#   ['entertainment/181bddea.png', 9, 'entertainment']]}

# %%
with open('./CoOp/data/tagging/split_zhou_Tagging.json', 'w') as f:
    json.dump(dict_file, f, indent=4)
